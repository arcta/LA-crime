# %% [markdown]
# # Taxonomy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data/2017.csv')
taxonomy = df[['stat','stat_desc','category']]\
    .groupby(['stat','stat_desc','category'])\
    .count()\
    .reset_index()\
    .sort_values('stat')

taxonomy.head()
# Out:
#    stat                                          stat_desc           category
# 0    11                          criminal homicide: murder  criminal homicide
# 1    21     rape, forcible: rape by force, female 18 yrs +      forcible rape
# 2    22  rape, forcible: attempt rape by force, female ...      forcible rape
# 3    23                     rape by force, female under 18      forcible rape
# 4    24             attempt forcible rape, female under 18      forcible rape

# %% [markdown]
# Categorization changes through the years, new sub-categories arrive, other drop; we need them all merged together:

# %%
print('Year distinct `STAT` values count:')
for Y in range(2005, 2017):
    df = pd.read_csv('data/{}.csv'.format(Y))[['stat','stat_desc','category']]\
        .groupby(['stat','stat_desc','category'])\
        .count()\
        .reset_index()
    print(Y, len(df))
    # merge with year-suffix
    taxonomy = taxonomy.join(df.set_index('stat'), on = 'stat', how = 'outer',
                             lsuffix = '', rsuffix = '_{}'.format(Y))
    # make sure the main columns have all the values set: combined all the years through
    taxonomy.loc[taxonomy['stat_desc'].isnull(),'stat_desc'] =\
        taxonomy.loc[taxonomy['stat_desc'].isnull(),'stat_desc_{}'.format(Y)]
    taxonomy.loc[taxonomy['category'].isnull(),'category'] =\
        taxonomy.loc[taxonomy['category'].isnull(),'category_{}'.format(Y)]

print(2017, len(taxonomy))
# Out:
# Year distinct `STAT` values count:
# 2005 249
# 2006 249
# 2007 249
# 2008 249
# 2009 247
# 2010 244
# 2011 241
# 2012 247
# 2013 244
# 2014 239
# 2015 246
# 2016 328
# 2017 370

# %%
print('Joined: {}'.format(len(taxonomy)))
taxonomy.tail()
# Out:
# Joined: 370
#      stat                                          stat_desc  \
# 329   701                        non-criminal: alarm-robbery
# 329   703                           non-criminal: fire alarm
# 329   722           vehicle/boating laws, citations: parking
# 329   739  vehicle/boat, other non-criminal: right capsiz...
# 329   777  assist citizen -notification of high risk sex ...
#
#                        category stat_desc_2005 category_2005 stat_desc_2006  \
# 329  miscellaneous non-criminal            NaN           NaN            NaN
# 329  miscellaneous non-criminal            NaN           NaN            NaN
# 329  miscellaneous non-criminal            NaN           NaN            NaN
# 329  miscellaneous non-criminal            NaN           NaN            NaN
# 329  miscellaneous non-criminal            NaN           NaN            NaN
#
#     category_2006 stat_desc_2007 category_2007 stat_desc_2008  \
# 329           NaN            NaN           NaN            NaN
# 329           NaN            NaN           NaN            NaN
# 329           NaN            NaN           NaN            NaN
# 329           NaN            NaN           NaN            NaN
# 329           NaN            NaN           NaN            NaN
#
#                 ...             stat_desc_2012 category_2012 stat_desc_2013  \
# 329             ...                        NaN           NaN            NaN
# 329             ...                        NaN           NaN            NaN
# 329             ...                        NaN           NaN            NaN
# 329             ...                        NaN           NaN            NaN
# 329             ...                        NaN           NaN            NaN
#
#     category_2013 stat_desc_2014 category_2014 stat_desc_2015 category_2015  \
# 329           NaN            NaN           NaN            NaN           NaN
# 329           NaN            NaN           NaN            NaN           NaN
# 329           NaN            NaN           NaN            NaN           NaN
# 329           NaN            NaN           NaN            NaN           NaN
# 329           NaN            NaN           NaN            NaN           NaN
#
#                                         stat_desc_2016  \
# 329                        non-criminal: alarm-robbery
# 329                           non-criminal: fire alarm
# 329           vehicle/boating laws, citations: parking
# 329  vehicle/boat, other non-criminal: right capsiz...
# 329  assist citizen -notification of high risk sex ...
#
#                   category_2016
# 329  miscellaneous non-criminal
# 329  miscellaneous non-criminal
# 329  miscellaneous non-criminal
# 329  miscellaneous non-criminal
# 329  miscellaneous non-criminal
#
# [5 rows x 27 columns]

# %%
len(taxonomy)
# Out:
# 370

# %%
taxonomy = taxonomy[['stat','stat_desc','category']]

# %%
def collapse(x):
    """short category: single word"""

    if x == 'criminal homicide':
        return 'homicide'
    if x == 'forcible rape':
        return 'rape'
    if x == 'grand theft auto':
        return 'gta'
    if x[:13] == 'drunk driving':
        return 'dui'
    if x == 'larceny theft':
        return 'theft'
    if x == 'offenses against family':
        return 'family'
    if 'assault' in x:
        return 'assault'
    return x.split()[0]


taxonomy['short_cat'] = taxonomy['category'].apply(collapse)
taxonomy.head()
# Out:
#    stat                                          stat_desc           category  \
# 0    11                          criminal homicide: murder  criminal homicide
# 1    21     rape, forcible: rape by force, female 18 yrs +      forcible rape
# 2    22  rape, forcible: attempt rape by force, female ...      forcible rape
# 3    23                     rape by force, female under 18      forcible rape
# 4    24             attempt forcible rape, female under 18      forcible rape
#
#   short_cat
# 0  homicide
# 1      rape
# 2      rape
# 3      rape
# 4      rape

# %% [markdown]
# Let us set some useful indicators.

# %%
taxonomy['criminal'] = taxonomy['stat_desc'].apply(lambda x: 0 if 'non-criminal' in x else 1)
taxonomy.loc[taxonomy['stat'] > 700, 'criminal'] = 0
for x in ['accident','suicide','person dead']:
    taxonomy.loc[:,'criminal'] = taxonomy.apply(lambda r: 0 if x in r['stat_desc'] else r['criminal'], axis = 1)

# %%
taxonomy['violent'] = taxonomy['stat'].apply(lambda x: 1 if x < 62 else 0)
for x in ['violence','by force','assault','abuse','hit and run','hate','arson','kidnapping','vandalism']:
    taxonomy.loc[:,'violent'] = taxonomy.apply(lambda r: 1 if x in r['stat_desc'] else r['violent'], axis = 1)

# %%
taxonomy['weapon'] = taxonomy['stat_desc'].apply(lambda x: 1 if 'weapon' in x else 0)
for x in ['gun','knife','firearm','shooting']:
    taxonomy.loc[:,'weapon'] = taxonomy.apply(lambda r: 1 if x in r['stat_desc'] else r['weapon'], axis = 1)

# %%
taxonomy['gun'] = taxonomy['stat_desc'].apply(lambda x: 1 if 'gun' in x else 0)
for x in ['firearm','shooting']:
    taxonomy.loc[:,'gun'] = taxonomy.apply(lambda r: 1 if x in r['stat_desc'] else r['gun'], axis = 1)

# %%
taxonomy['misdemeanor'] = taxonomy['stat_desc'].apply(lambda x: 1 if 'misd' in x else 0)
taxonomy = taxonomy.sort_values(by = 'stat')

# %% [markdown]
# There we go:

# %%
print('stat C:?  M:?  V:?  W:?  G:?   description')
print('----------------------------------------------------------------------------------')
for i in range(len(taxonomy)):
    print('{:<4} C:{}  M:{}  V:{}  W:{}  G:{}   {}'.format(taxonomy.iloc[i]['stat'],
                                                           taxonomy.iloc[i]['criminal'],
                                                           taxonomy.iloc[i]['misdemeanor'],
                                                           taxonomy.iloc[i]['violent'],
                                                           taxonomy.iloc[i]['weapon'],
                                                           taxonomy.iloc[i]['gun'],
                                                           taxonomy.iloc[i]['stat_desc']))
# Out:
# stat C:?  M:?  V:?  W:?  G:?   description
# ----------------------------------------------------------------------------------
# 11   C:1  M:0  V:1  W:0  G:0   criminal homicide: murder
# 12   C:1  M:0  V:1  W:0  G:0   criminal homicide: manslaughter, voluntary/involuntary
# 13   C:1  M:0  V:1  W:1  G:1   deputy involved shooting/suspect dead
# 21   C:1  M:0  V:1  W:0  G:0   rape, forcible: rape by force, female 18 yrs +
# 22   C:1  M:0  V:1  W:0  G:0   rape, forcible: attempt rape by force, female 18 yrs +
# 23   C:1  M:0  V:1  W:0  G:0   rape by force, female under 18
# 24   C:1  M:0  V:1  W:0  G:0   attempt forcible rape, female under 18
# 25   C:1  M:0  V:1  W:0  G:0   rape by force, male 18 and over
# 26   C:1  M:0  V:1  W:0  G:0   attempt rape by force, male 18 and over
# 27   C:1  M:0  V:1  W:0  G:0   rape by force, male under 18
# 28   C:1  M:0  V:1  W:0  G:0   attempt rape by force, male under 18
# 31   C:1  M:0  V:1  W:1  G:0   robbery, weapon: highway, etc.
# 32   C:1  M:0  V:1  W:1  G:0   robbery, weapon: store, business, hotel, motel, etc.
# 33   C:1  M:0  V:1  W:1  G:0   robbery, weapon: service station
# 34   C:1  M:0  V:1  W:1  G:0   robbery, weapon: convenience store, fast food, restaurant
# 35   C:1  M:0  V:1  W:1  G:0   robbery, weapon: residence
# 36   C:1  M:0  V:1  W:1  G:0   robbery, weapon: bank
# 37   C:1  M:0  V:1  W:1  G:0   robbery, weapon: other
# 38   C:1  M:0  V:1  W:1  G:0   robbery, weapon: carjacking
# 39   C:1  M:0  V:1  W:1  G:0   robbery, weapon: cargo hijacking
# 41   C:1  M:0  V:1  W:0  G:0   robbery, strong-arm: highway, etc.
# 42   C:1  M:0  V:1  W:0  G:0   robbery, strong-arm: store, business, hotel, motel, etc.
# 43   C:1  M:0  V:1  W:0  G:0   robbery, strong-arm: service station
# 44   C:1  M:0  V:1  W:0  G:0   robbery, strong-arm: convenience store, fast food, restaurant
# 45   C:1  M:0  V:1  W:0  G:0   robbery, strong-arm: residence
# 46   C:1  M:0  V:1  W:0  G:0   robbery, strong-arm: bank
# 47   C:1  M:0  V:1  W:0  G:0   robbery, strong-arm: other
# 48   C:1  M:0  V:1  W:0  G:0   robbery, strong-arm: carjacking
# 49   C:1  M:0  V:1  W:0  G:0   robbery, strong-arm: cargo hijacking
# 50   C:1  M:0  V:1  W:0  G:0   assault, aggravated: domestic violence
# 51   C:1  M:0  V:1  W:1  G:1   assault, aggravated: adw - gun
# 52   C:1  M:0  V:1  W:1  G:0   assault, aggravated: adw - knife
# 53   C:1  M:0  V:1  W:1  G:0   assault, aggravated: adw - other dangerous weapon
# 54   C:1  M:0  V:1  W:0  G:0   assault, aggravated: adw - hands, feet, fist, etc.
# 55   C:1  M:0  V:1  W:1  G:1   assault, aggravated: adw, peace officer - gun
# 56   C:1  M:0  V:1  W:1  G:0   assault, aggravated: adw, peace officer - knife
# 57   C:1  M:0  V:1  W:1  G:0   assault, aggravated: adw, peace officer - other dangerous weapon
# 58   C:1  M:0  V:1  W:0  G:0   assault, felony: adw, peace officer - hands, feet, fist, etc.
# 59   C:1  M:0  V:1  W:0  G:0   assault, aggravated: child assault
# 61   C:1  M:0  V:1  W:0  G:0   burglary, residence: night, entry by force
# 62   C:1  M:0  V:0  W:0  G:0   burglary, residence: night, entry no force
# 63   C:1  M:0  V:0  W:0  G:0   burglary, residence: night, attempt
# 64   C:1  M:0  V:1  W:0  G:0   burglary, residence: day, entry by force
# 65   C:1  M:0  V:0  W:0  G:0   burglary, residence: day, entry no force
# 66   C:1  M:0  V:0  W:0  G:0   burglary, residence: day, attempt
# 67   C:1  M:0  V:1  W:0  G:0   burglary, residence: unknown, entry by force
# 68   C:1  M:0  V:0  W:0  G:0   burglary, residence: unknown, entry no force
# 69   C:1  M:0  V:0  W:0  G:0   burglary, residence: unknown, attempt
# 71   C:1  M:0  V:1  W:0  G:0   burglary, other structure: night, entry by force
# 72   C:1  M:0  V:0  W:0  G:0   burglary, other structure: night, entry no force
# 73   C:1  M:0  V:0  W:0  G:0   burglary, other structure: night, attempt
# 74   C:1  M:0  V:1  W:0  G:0   burglary, other structure: day, entry by force
# 75   C:1  M:0  V:0  W:0  G:0   burglary, other structure: day, entry no force
# 76   C:1  M:0  V:0  W:0  G:0   burglary, other structure: day, attempt
# 77   C:1  M:0  V:1  W:0  G:0   burglary, other structure: unknown, entry by force
# 78   C:1  M:0  V:0  W:0  G:0   burglary, other structure: unknown, entry no force
# 79   C:1  M:0  V:0  W:0  G:0   burglary, other structure: unknown, attempt
# 80   C:1  M:0  V:0  W:0  G:0   grand theft: boat
# 81   C:1  M:0  V:0  W:0  G:0   grand theft: pick pocket
# 82   C:1  M:0  V:0  W:0  G:0   grand theft: purse snatch
# 83   C:1  M:0  V:0  W:0  G:0   grand theft: shoplifting (from dept store, mkt gas sta)
# 84   C:1  M:0  V:0  W:0  G:0   grand theft: from unlocked auto
# 85   C:1  M:0  V:0  W:0  G:0   grand theft: auto parts and accessories
# 86   C:1  M:0  V:0  W:0  G:0   grand theft: bicycles
# 87   C:1  M:0  V:0  W:0  G:0   grand theft: from bldg(churches, schools, restaurants, offices, etc)
# 88   C:1  M:0  V:0  W:0  G:0   grand theft: from coin operated machine
# 89   C:1  M:0  V:0  W:0  G:0   grand theft: other (from boat, plane, prvt res, yard, etc)
# 90   C:1  M:0  V:0  W:0  G:0   grand theft vehicle (gta): cargo/vehicle, laden with freight
# 91   C:1  M:0  V:0  W:0  G:0   grand theft vehicle (gta): automobile/passenger van
# 92   C:1  M:0  V:0  W:0  G:0   grand theft vehicle (gta): automobile/passenger van, attempt
# 93   C:1  M:0  V:0  W:0  G:0   grand theft vehicle (gta): truck, motor home, cargo van
# 94   C:1  M:0  V:0  W:0  G:0   grand theft vehicle (gta): truck, motor home, cargo van, attempt
# 95   C:1  M:0  V:0  W:0  G:0   grand theft vehicle (gta): motorcycle
# 96   C:1  M:0  V:0  W:0  G:0   grand theft vehicle (gta): motorcycle, attempt
# 97   C:1  M:0  V:0  W:0  G:0   grand theft vehicle (gta): other veh (snowmobile, golf cart, etc)
# 98   C:1  M:0  V:0  W:0  G:0   grand theft vehicle (gta): other veh, attempt(snowmobile, golf cart)
# 99   C:1  M:0  V:0  W:0  G:0   grand theft vehicle (gta): bus
# 101  C:1  M:0  V:0  W:0  G:0   worthless documents/forgery: nsf/account closed/checks - over $200
# 102  C:1  M:0  V:0  W:0  G:0   worthless documents/forgery: nsf/account closed/checks-$200 or less
# 103  C:1  M:0  V:0  W:0  G:0   worthless documents/forgery: forgery - checks/money orders
# 104  C:1  M:0  V:0  W:0  G:0   worthless documents/forgery: forgery - prescriptions
# 105  C:1  M:0  V:0  W:0  G:0   worthless documents/forgery: forgery - credit cards/sales slips
# 106  C:1  M:0  V:0  W:0  G:0   worthless documents/forgery: possess of completed checks/money order
# 107  C:1  M:0  V:0  W:0  G:0   worthless documents/forgery: forgery - other
# 111  C:1  M:0  V:0  W:0  G:0   fraud: fraudulent credit applications
# 112  C:1  M:0  V:0  W:0  G:0   fraud: fraud by false pretenses
# 113  C:1  M:0  V:0  W:0  G:0   fraud: fraud by trick or device - over $400
# 114  C:1  M:0  V:0  W:0  G:0   fraud: fraud by trick or device - $400 or less
# 115  C:1  M:0  V:0  W:0  G:0   fraud: computer system crimes
# 116  C:1  M:0  V:0  W:0  G:0   fraud: obtaining trade secrets by fraud
# 117  C:1  M:0  V:0  W:0  G:0   identity theft (goods/services/credit)
# 118  C:1  M:0  V:0  W:0  G:0   identity theft (utilities)
# 119  C:1  M:0  V:0  W:0  G:0   identity theft, attempt/possession of profile info
# 120  C:1  M:0  V:0  W:0  G:0   sex felonies: sex crimes against children (under 14 years)
# 121  C:1  M:0  V:0  W:0  G:0   sex felonies: unlawful sexual intercourse
# 122  C:1  M:0  V:0  W:0  G:0   exploitation of child via internet
# 123  C:1  M:0  V:0  W:0  G:0   sex felonies: incest
# 124  C:1  M:0  V:0  W:0  G:0   sex felonies: pandering
# 125  C:1  M:0  V:0  W:0  G:0   sex felonies: pimping
# 126  C:1  M:0  V:0  W:0  G:0   failing to register as sex offender - felony
# 127  C:1  M:0  V:0  W:0  G:0   oral copulation
# 128  C:1  M:0  V:0  W:0  G:0   sex felonies: sodomy
# 129  C:1  M:0  V:0  W:0  G:0   sex felonies: all other sex felonies
# 130  C:1  M:1  V:0  W:0  G:0   sex misdemeanors: indecent exposure
# 132  C:1  M:1  V:0  W:0  G:0   sex misdemeanors: keep/live house of ill fame
# 133  C:1  M:1  V:0  W:0  G:0   sex misdemeanors: engage/solicit lewd or obscene conduct
# 134  C:1  M:1  V:0  W:0  G:0   sex misdemeanors: annoy/molest children
# 135  C:1  M:1  V:0  W:0  G:0   expliotation of child via internet (misd)
# 136  C:1  M:1  V:0  W:0  G:0   sex misdemeanors: prostitution, solicit/engage/seduce minor under 18
# 137  C:1  M:0  V:0  W:0  G:0   child pornography
# 138  C:1  M:1  V:0  W:0  G:0   failing to register as sex offender - misd.
# 139  C:1  M:1  V:0  W:0  G:0   sex misdemeanors: all other sex misdemeanors
# 144  C:1  M:0  V:1  W:0  G:0   assault, non-agg: hands, feet, fist, etc.
# 145  C:1  M:0  V:1  W:0  G:0   assault, non-agg: obstruct/resist/battery peace officer
# 146  C:1  M:0  V:1  W:0  G:0   assault, non-aggravated: domestic violence
# 147  C:1  M:0  V:1  W:0  G:0   assault, non-agg: threat public/school official
# 149  C:1  M:0  V:1  W:0  G:0   assault, non-agg: child assault
# 151  C:1  M:0  V:0  W:1  G:0   weapon laws: felony
# 152  C:1  M:1  V:0  W:1  G:0   weapon laws: misdemeanor
# 153  C:1  M:0  V:0  W:1  G:1   weapon laws: shooting, unlawful
# 154  C:1  M:0  V:0  W:1  G:0   weapon laws: weapons of mass destruction: felony
# 155  C:1  M:0  V:0  W:1  G:1   weapon laws: firearm w/narcotics: felony
# 161  C:1  M:1  V:0  W:0  G:0   defrauding: defrauding innkeeper (fel or misd)
# 162  C:1  M:1  V:0  W:0  G:0   defrauding: defrauding public convey/util. (fel or misd)
# 163  C:1  M:1  V:0  W:0  G:0   defrauding: welfare fraud (fel or misd)
# 165  C:1  M:1  V:0  W:0  G:0   defrauding: embezzlement (misd)
# 171  C:1  M:0  V:0  W:0  G:0   offenses against family: abandonment
# 172  C:1  M:0  V:0  W:0  G:0   offenses against family: child neglect
# 173  C:1  M:0  V:0  W:0  G:0   offenses against family: failure to provide
# 174  C:1  M:0  V:1  W:0  G:0   offenses against family: elder abuse
# 175  C:1  M:0  V:1  W:0  G:0   offenses against family: domestic violence (other than phys assault)
# 176  C:1  M:0  V:1  W:0  G:0   mental elder/dependent adult abuse
# 177  C:1  M:0  V:1  W:0  G:0   fiduciary elder/dependent adult abuse
# 178  C:1  M:0  V:1  W:0  G:0   dependent adult abuse: mental, physical, fuduciary
# 181  C:1  M:0  V:0  W:0  G:0   felony transport. &/or sale of controlled substance(excpt marijuana)
# 182  C:1  M:0  V:0  W:0  G:0   felony transport,sales,possess marijuana,concentrtd cannabis/hashsh
# 183  C:1  M:0  V:0  W:0  G:0   under the influence of narcotic 11550 hs. does not incl 647(f)pc
# 184  C:1  M:0  V:0  W:0  G:0   felony possession of a controlled substance (excluding marijuana)
# 185  C:1  M:1  V:0  W:0  G:0   misdemeanor possessn of a controlled substance (excluding marijuana)
# 186  C:1  M:0  V:0  W:0  G:0   found narcotics
# 187  C:1  M:0  V:0  W:0  G:0   narcotics: miscellaneous felonies
# 188  C:1  M:1  V:0  W:0  G:0   narcotics: marijuana misdemeanors (more than 1 oz)
# 189  C:1  M:1  V:0  W:0  G:0   narcotics: marijuana misdemeanors (less than 1 oz)
# 191  C:1  M:0  V:0  W:0  G:0   liquor laws: sell liquor to minor
# 192  C:1  M:0  V:0  W:0  G:0   liquor laws: possession/use/furnish minor false evidence of age
# 193  C:1  M:0  V:0  W:0  G:0   liquor laws: possession of alcohol by minor
# 194  C:1  M:0  V:0  W:0  G:0   liquor laws: minor on premises/employ minor on premises
# 195  C:1  M:0  V:0  W:0  G:0   liquor laws: drinking in vehicle
# 196  C:1  M:0  V:0  W:0  G:0   liquor laws: possession open container (county or city park)
# 197  C:1  M:0  V:0  W:0  G:0   liquor laws: storage of open container
# 198  C:1  M:0  V:0  W:0  G:0   liquor laws: all other liquor law violations
# 199  C:1  M:0  V:0  W:0  G:0   tobacco laws: furnishing tobacco to minors
# 201  C:1  M:0  V:0  W:0  G:0   drunk: alcohol
# 202  C:1  M:0  V:0  W:0  G:0   drunk: drugs
# 210  C:1  M:0  V:0  W:0  G:0   disorderly conduct: interfering w/school activities
# 212  C:1  M:0  V:0  W:0  G:0   disorderly conduct: disturbing the peace/court disturbances
# 213  C:1  M:0  V:0  W:0  G:0   disorderly conduct: unlawful assembly/fail to disperse
# 214  C:1  M:0  V:0  W:0  G:0   disorderly conduct: riot or rout
# 216  C:1  M:0  V:0  W:0  G:0   disorderly conduct: peeping and/or prowling
# 217  C:1  M:0  V:0  W:0  G:0   disorderly conduct: telephone annoyance
# 218  C:1  M:0  V:0  W:0  G:0   loud party-warning notice issued/rpt taken
# 219  C:1  M:0  V:0  W:0  G:0   loud party - verbal warning issued
# 221  C:1  M:0  V:0  W:0  G:0   vagrancy: loitering/curfew
# 222  C:1  M:0  V:0  W:0  G:0   vagrancy/quality of life:illegal vending
# 231  C:1  M:0  V:0  W:0  G:0   gambling: gambling/touting
# 233  C:1  M:0  V:0  W:0  G:0   gambling: bookmaking
# 234  C:1  M:0  V:0  W:0  G:0   gambling: lotteries and numbers games (pools)
# 241  C:1  M:0  V:0  W:0  G:0   drunk driving - vehicle/boat: alcohol/drugs (injury/death), felony
# 242  C:1  M:0  V:0  W:0  G:0   drunk driving - vehicle/boat: alc/drugs
# 243  C:1  M:0  V:0  W:0  G:0   drunk driving - vehicle/boat: alcohol at .08% or above
# 245  C:1  M:0  V:0  W:0  G:0   drunk driving - vehicle/boat: drugs only
# 250  C:1  M:1  V:1  W:0  G:0   vehicle and boating laws: hit and run, misdemeanor
# 251  C:1  M:0  V:1  W:0  G:0   vehicle and boating laws: hit and run, felony (cause inj or death)
# 252  C:1  M:0  V:0  W:0  G:0   vehicle and boating laws: felony
# 255  C:1  M:1  V:0  W:0  G:0   vehicle and boating laws: misdemeanor
# 256  C:1  M:0  V:0  W:0  G:0   vehicle and boating laws: juvenile zero tolerance
# 261  C:1  M:1  V:1  W:0  G:0   vandalism misd
# 262  C:1  M:0  V:1  W:0  G:0   vandalism: vandalism jail
# 263  C:1  M:0  V:1  W:0  G:0   vandalism felony
# 264  C:1  M:0  V:1  W:0  G:0   vandalism: graffiti/tagging
# 270  C:1  M:0  V:1  W:0  G:0   arson: single occupancy residential
# 271  C:1  M:0  V:1  W:0  G:0   arson: other residential (apts, hotels, dorms, etc)
# 272  C:1  M:0  V:1  W:0  G:0   arson: storage (barns, garages, warehouses, etc)
# 273  C:1  M:0  V:1  W:0  G:0   arson: industrial/manufacturing
# 274  C:1  M:0  V:1  W:0  G:0   arson: other commercial (stores, restaurants, etc)
# 275  C:1  M:0  V:1  W:0  G:0   arson: community/public (churches, jails, schools, etc)
# 276  C:1  M:0  V:1  W:0  G:0   arson: all other structures (bldg under construction)
# 277  C:1  M:0  V:1  W:0  G:0   arson: motor vehicles (autos, trucks, buses, m/c etc)
# 278  C:1  M:0  V:1  W:0  G:0   arson: other mobile property (trailer, boat, airplane, motor home)
# 279  C:1  M:0  V:1  W:0  G:0   arson: all others
# 280  C:1  M:0  V:0  W:0  G:0   warrants: traffic
# 283  C:1  M:0  V:0  W:0  G:0   warrants: felony, in county
# 285  C:1  M:0  V:0  W:0  G:0   warrants: felony, out of county
# 286  C:1  M:1  V:0  W:0  G:0   warrants: misdemeanor
# 287  C:1  M:0  V:0  W:0  G:0   warrants: warrant service no booking
# 290  C:1  M:0  V:0  W:0  G:0   receiving stolen property: receiving stolen property
# 301  C:1  M:0  V:0  W:0  G:0   federal offenses without money: immigration laws - illegal entry
# 302  C:1  M:0  V:0  W:0  G:0   federal offenses without money: counterfeiting federal documents
# 303  C:1  M:0  V:0  W:0  G:0   federal offenses without money: desertion, a.w.o.l.
# 304  C:1  M:0  V:0  W:0  G:0   federal offenses without money: smuggling
# 305  C:1  M:0  V:0  W:0  G:0   federal offenses without money: tampering with mail
# 308  C:1  M:0  V:0  W:0  G:0   federal offenses without money: all other fed offenses without money
# 311  C:1  M:0  V:0  W:0  G:0   federal offenses with money: defraud federal government
# 312  C:1  M:0  V:0  W:0  G:0   federal offenses with money: mail fraud
# 314  C:1  M:0  V:0  W:0  G:0   federal offenses with money: theft of mail
# 315  C:1  M:0  V:0  W:0  G:0   federal offenses with money: counterfeiting u.s. money
# 316  C:1  M:0  V:0  W:0  G:0   federal offenses with money: all other federal offenses with money
# 321  C:1  M:0  V:0  W:0  G:0   felonies, miscellaneous: bigamy
# 322  C:1  M:0  V:0  W:0  G:0   felonies, miscellaneous: conspiracy
# 323  C:1  M:0  V:0  W:0  G:0   felonies, miscellaneous: escape, adult/juvenile
# 324  C:1  M:0  V:0  W:0  G:0   felonies, miscellaneous: extortion
# 325  C:1  M:0  V:0  W:0  G:0   felonies, miscellaneous: perjury
# 326  C:1  M:0  V:1  W:0  G:0   felonies, miscellaneous: kidnapping
# 327  C:1  M:0  V:0  W:0  G:0   felonies, miscellaneous: child stealing
# 328  C:1  M:0  V:0  W:0  G:0   felonies, miscellaneous: false report bomb/emergency
# 329  C:1  M:0  V:0  W:0  G:0   felonies, miscellaneous: false imprisonment
# 330  C:1  M:0  V:0  W:0  G:0   felonies, miscellaneous: embezzlement, felony
# 331  C:1  M:0  V:0  W:0  G:0   felonies, miscellaneous: solicit to commit murder/rape/certain fel
# 332  C:1  M:0  V:0  W:0  G:0   felonies, miscellaneous: lynching
# 333  C:1  M:0  V:0  W:0  G:0   felonies, miscellaneous: unlawful use explosives
# 334  C:1  M:0  V:0  W:0  G:0   felonies, miscellaneous: unlawful possession explosives
# 335  C:1  M:0  V:0  W:0  G:0   felonies, miscellaneous: aid/abetting escape
# 336  C:1  M:0  V:0  W:0  G:0   felonies, miscellaneous: bribery
# 338  C:1  M:0  V:0  W:0  G:0   felonies, misc: manslaughter, negligent driving (192(c)(1) p.c.)
# 339  C:1  M:0  V:0  W:0  G:0   felonies, miscellaneous: all other felonies
# 340  C:1  M:0  V:0  W:0  G:0   vehicle burglary: auto/passenger van burglary
# 341  C:1  M:0  V:0  W:0  G:0   vehicle burglary: attempt auto/passenger van burglary
# 342  C:1  M:0  V:0  W:0  G:0   vehicle burglary: truck/cargo van burglary
# 343  C:1  M:0  V:0  W:0  G:0   vehicle burglary: attempt truck/cargo van burglary
# 344  C:1  M:0  V:0  W:0  G:0   vehicle burglary: other vehicle burglary
# 345  C:1  M:0  V:0  W:0  G:0   vehicle burglary: attempt other vehicle
# 350  C:1  M:0  V:0  W:0  G:0   locker burglary
# 351  C:1  M:0  V:0  W:0  G:0   attempt locker burglary
# 360  C:1  M:0  V:0  W:0  G:0   boat burglary: boat burglary
# 361  C:1  M:0  V:0  W:0  G:0   boat burglary: attempt boat burglary
# 370  C:1  M:0  V:0  W:0  G:0   aircraft burglary: aircraft burglary
# 382  C:1  M:0  V:0  W:0  G:0   theft, petty: boat
# 383  C:1  M:0  V:0  W:0  G:0   theft, petty: shoplifting (from dept store, mkt, etc)
# 384  C:1  M:0  V:0  W:0  G:0   theft, petty: from auto (except parts/accessories)
# 385  C:1  M:0  V:0  W:0  G:0   theft, petty: auto parts and accessories
# 386  C:1  M:0  V:0  W:0  G:0   theft, petty: bicycles
# 387  C:1  M:0  V:0  W:0  G:0   theft, petty: from bldgs (church, school, restaurant)
# 388  C:1  M:0  V:0  W:0  G:0   theft, petty: from coin operated machine
# 389  C:1  M:0  V:0  W:0  G:0   theft, petty: other (from prvt res, boat, plane,yard)
# 390  C:1  M:1  V:0  W:0  G:0   misdemeanors, miscellaneous: cruelty to animals
# 391  C:1  M:1  V:0  W:0  G:0   misdemeanors, miscellaneous: trespassing
# 392  C:1  M:1  V:0  W:0  G:0   misdemeanors, miscellaneous: public nuisance
# 393  C:1  M:1  V:0  W:0  G:0   misdemeanors, miscellaneous: fish and game violation
# 395  C:1  M:1  V:0  W:0  G:0   misdemeanors, misc: manslaughter, non-neg driving (192(c)(2) p.c.)
# 396  C:1  M:1  V:0  W:0  G:0   misdemeanors, miscellaneous: contributing to delinquency
# 397  C:1  M:1  V:0  W:0  G:0   misdemeanors, miscellaneous: parole/probation violation
# 398  C:1  M:1  V:0  W:0  G:0   misdemeanors, miscellaneous: alarm violations
# 399  C:1  M:1  V:0  W:0  G:0   misdemeanors, miscellaneous: all other misdemeanors
# 400  C:1  M:0  V:0  W:0  G:0   persons missing or found: adult, missing, lost or found
# 401  C:1  M:0  V:0  W:0  G:0   persons missing or found: juvenile, found
# 402  C:1  M:0  V:0  W:0  G:0   persons missing or found: juvenile, lost, runaway or missing
# 403  C:1  M:0  V:0  W:0  G:0   juvenile lost,missing or runaway, courtesy report for another agency
# 410  C:0  M:0  V:0  W:0  G:0   juvenile, non-criminal: dependent child of court (wic 300(a) - (j))
# 414  C:0  M:0  V:0  W:0  G:0   juvenile, non-criminal: juvenile incorrigible, (wic 601)
# 415  C:0  M:0  V:0  W:0  G:0   juvenile, non-criminal: juv school laws, habitual truancy (wic 601b)
# 416  C:1  M:0  V:1  W:0  G:0   suspected child abuse report (scar)  further investigation required
# 418  C:0  M:0  V:1  W:0  G:0    non-criminal: suspicious circumstances, poss. child abuse
# 419  C:1  M:0  V:1  W:0  G:0   suspected child abuse report - scar
# 420  C:1  M:0  V:0  W:0  G:0   commitments: drunk commitment
# 422  C:1  M:0  V:0  W:0  G:0   commitments: involuntary narcotic commitment
# 431  C:1  M:0  V:0  W:0  G:0   immigration: false docs-manufac/sale,conceal true citizenship,felony
# 432  C:1  M:0  V:0  W:0  G:0   immigration: false documents-use to conceal true citizenship-felony
# 436  C:1  M:1  V:0  W:0  G:0   immigration: false docs-gov't-manufac/sale,conceal true citizen,misd
# 440  C:0  M:0  V:0  W:1  G:1   non-criminal: other, explosion, poss narc act, surrender firearms
# 441  C:0  M:0  V:0  W:0  G:0   non-criminal: special investigations
# 442  C:0  M:0  V:0  W:0  G:0   non-criminal: property lost/found/recovered
# 443  C:0  M:0  V:0  W:0  G:0   non-criminal: erroneous release
# 444  C:0  M:0  V:0  W:0  G:0   non-criminal: suspicious circumstances, possible criminal activity
# 445  C:0  M:0  V:0  W:0  G:0   non-criminal: fire, non-criminal
# 446  C:0  M:0  V:0  W:0  G:0   non-criminal: liquor and business license investigations
# 447  C:0  M:0  V:0  W:0  G:0   non-criminal: abandoned auto/boat
# 448  C:0  M:0  V:0  W:0  G:0   non-criminal: labor dispute/strike
# 449  C:0  M:0  V:1  W:0  G:0   non-criminal: domestic violence
# 451  C:0  M:0  V:0  W:0  G:0   suicide and attempt: suicide, adult
# 452  C:0  M:0  V:0  W:0  G:0   suicide and attempt: suicide, juvenile
# 453  C:0  M:0  V:0  W:0  G:0   suicide and attempt: suicide, inmate
# 455  C:0  M:0  V:0  W:0  G:0   suicide and attempt: attempt suicide, adult
# 456  C:0  M:0  V:0  W:0  G:0   suicide and attempt: attempt suicide, juvenile
# 457  C:0  M:0  V:0  W:0  G:0   suicide and attempt: attempt suicide, inmate
# 458  C:0  M:0  V:0  W:0  G:0   suicide and attempt: inmate injury/feigned attempt suicide
# 461  C:1  M:0  V:0  W:0  G:0   person(s) mentally ill - 5150 hold placed
# 462  C:1  M:0  V:0  W:0  G:0   person(s) mentally ill -escapee
# 470  C:0  M:0  V:0  W:0  G:0   accidents, traffic-vehicle or boat: accident, traffic (fatal)
# 471  C:0  M:0  V:0  W:0  G:0   accidents, traffic-vehicle or boat: accident, traf w/inj(non-fatal)
# 472  C:0  M:0  V:0  W:0  G:0   accidents, traffic-vehicle or boat: traffic (non-injury)
# 481  C:0  M:0  V:0  W:0  G:0   accidents, miscellaneous: accident, non-traffic
# 483  C:0  M:0  V:0  W:0  G:0   accidents, miscellaneous: accident, traffic (off highway)
# 485  C:0  M:0  V:0  W:1  G:1   accidents, miscellaneous: accidental shooting, no injury
# 486  C:0  M:0  V:0  W:1  G:1   accidents, miscellaneous: accidental shooting, injury
# 491  C:0  M:0  V:0  W:0  G:0   persons dead: person dead, natural causes
# 492  C:0  M:0  V:0  W:0  G:0   persons dead: person dead, industrial accident
# 493  C:0  M:0  V:0  W:0  G:0   persons dead: person dead, home accident
# 494  C:0  M:0  V:0  W:0  G:0   persons dead: person dead, recreational accident
# 495  C:0  M:0  V:0  W:0  G:0   persons dead: person dead, overdose narcotics/drugs
# 496  C:0  M:0  V:0  W:0  G:0   persons dead: person dead, other (unknown cause)
# 499  C:0  M:0  V:0  W:0  G:0   persons dead: person dead, inmate
# 500  C:1  M:0  V:0  W:0  G:0   miscellaneous: boat repossessed
# 501  C:1  M:0  V:0  W:0  G:0   miscellaneous: vehicle repossessed
# 502  C:1  M:0  V:0  W:0  G:0   miscellaneous: injury to county employee
# 503  C:1  M:0  V:0  W:0  G:0   miscellaneous: stolen/lost/found/license plates
# 504  C:1  M:0  V:0  W:0  G:0   miscellaneous: damage to county property
# 505  C:1  M:0  V:0  W:0  G:0   miscellaneous: use of force memo
# 506  C:1  M:0  V:0  W:0  G:0   miscellaneous: non-categorized incident
# 511  C:1  M:0  V:0  W:0  G:0   hazardous materials: illegal dumping of hazardous material
# 512  C:0  M:0  V:0  W:0  G:0   hazardous materials: accidental discharge
# 520  C:1  M:0  V:1  W:0  G:0   miscellaneous: hate crime (race)
# 521  C:1  M:0  V:1  W:0  G:0   miscellaneous: hate crime (ethnicity)
# 522  C:1  M:0  V:1  W:0  G:0   miscellaneous: hate crime (religion)
# 523  C:1  M:0  V:1  W:0  G:0   miscellaneous: hate crime (sexual orientation)
# 524  C:1  M:0  V:1  W:0  G:0   miscellaneous: hate crime (physical disability)
# 529  C:1  M:0  V:1  W:0  G:0   hate incidents - non criminal
# 602  C:1  M:0  V:0  W:0  G:0   reasonable cause arrests: rape, forcible and statutory
# 603  C:1  M:0  V:0  W:0  G:0   reasonable cause arrests: robbery
# 604  C:1  M:0  V:1  W:0  G:0   reasonable cause arrests: assault, felonious
# 605  C:1  M:0  V:0  W:0  G:0   reasonable cause arrests: burglary
# 606  C:1  M:0  V:0  W:0  G:0   reasonable cause arrests: grand theft
# 607  C:1  M:0  V:0  W:0  G:0   reasonable cause arrests: grand theft auto or motorcycle
# 609  C:1  M:0  V:0  W:0  G:0   reasonable cause arrests: all others
# 610  C:1  M:0  V:0  W:0  G:0   transit infraction: fare-related
# 611  C:1  M:0  V:0  W:0  G:0   transit infraction: quality-of-life violation
# 612  C:1  M:0  V:0  W:0  G:0   juvenile transit infraction: fare-related
# 680  C:0  M:0  V:0  W:0  G:0   non-criminal, custody incidents: inmate incidents
# 681  C:0  M:0  V:0  W:0  G:0   non-criminal, custody incidents - significant inmate incidents
# 682  C:0  M:0  V:0  W:0  G:0   non-criminal, custody incidents - minor inmate disturbance
# 683  C:0  M:0  V:0  W:0  G:0   non-criminal, custody incidents - major inmate disturbance
# 684  C:0  M:0  V:0  W:0  G:0   non-criminal, custody incidents - inmate riot
# 687  C:0  M:0  V:0  W:0  G:0   non-criminal, custody incidents - inmate sick/injured
# 689  C:0  M:0  V:0  W:0  G:0   non-criminal, custody incidents - inmate complaint
# 690  C:0  M:0  V:0  W:0  G:0   non-criminal, custody incidents - erroneous release
# 691  C:0  M:0  V:0  W:0  G:0   non-criminal, custody incidents - overdetention
# 695  C:1  M:0  V:0  W:0  G:0   unlawful possession of a wireless device in a custody facility
# 701  C:0  M:0  V:0  W:0  G:0   non-criminal: alarm-robbery
# 702  C:0  M:0  V:0  W:0  G:0   non-criminal: animals
# 703  C:0  M:0  V:0  W:0  G:0   non-criminal: fire alarm
# 705  C:0  M:0  V:0  W:0  G:0   issuance of restraining orders.
# 706  C:0  M:0  V:0  W:0  G:0   injury to community services worker/work release inmate
# 707  C:0  M:0  V:1  W:0  G:0   susp circs elder abuse
# 708  C:0  M:0  V:1  W:0  G:0   susp circs domestic violence
# 709  C:0  M:0  V:0  W:0  G:0   suspicious circumstance- possible terroist related incident
# 710  C:0  M:0  V:0  W:0  G:0   non-criminal: follow-up
# 713  C:0  M:0  V:0  W:0  G:0   non-criminal: rescue
# 714  C:0  M:0  V:0  W:0  G:0   non-criminal: safety hazard
# 715  C:0  M:0  V:1  W:0  G:0   non-criminal: elder abuse
# 716  C:0  M:0  V:0  W:0  G:0   non-criminal: suspicious person
# 719  C:0  M:0  V:0  W:0  G:0   non-criminal: foot patrol
# 720  C:0  M:0  V:0  W:0  G:0   vehicle/boating laws, citations: hazardous citation
# 721  C:0  M:0  V:0  W:0  G:0   vehicle/boating laws, citations: non-hazardous citation
# 722  C:0  M:0  V:0  W:0  G:0   vehicle/boating laws, citations: parking
# 723  C:0  M:0  V:0  W:0  G:0   vehicle/boating laws, citations: warning given
# 724  C:0  M:0  V:0  W:0  G:0   juvenile citation: infraction
# 725  C:0  M:0  V:0  W:0  G:0   juvenile citation: alcohol-related
# 727  C:0  M:0  V:0  W:0  G:0   juvenile citation: curfew
# 729  C:0  M:0  V:0  W:0  G:0   juvenile citation: truancy
# 730  C:0  M:0  V:0  W:0  G:0   vehicle/boat, other non-criminal: traffic hazard
# 731  C:0  M:0  V:0  W:0  G:0   vehicle/boat, other non-criminal: vehicle/boat disturbance
# 733  C:0  M:0  V:0  W:0  G:0   vehicle/boat, other non-criminal: veh/boat recovered (other juris)
# 734  C:0  M:0  V:0  W:0  G:0   vehicle/boat, other non-criminal: vehicle red tagged
# 735  C:0  M:0  V:0  W:0  G:0   vehicle/boat, other non-criminal: vehicle/boat, stored/impounded
# 736  C:0  M:0  V:0  W:0  G:0   vehicle/boat, other non-criminal: tow disabled boat
# 737  C:0  M:0  V:0  W:0  G:0   vehicle/boat, other non-criminal: pump sinking boat
# 738  C:0  M:0  V:0  W:0  G:0   vehicle/boat, other non-criminal: boat assist, other
# 739  C:0  M:0  V:0  W:0  G:0   vehicle/boat, other non-criminal: right capsized boat
# 740  C:0  M:0  V:0  W:0  G:0   vehicle/boat, other non-criminal: raise sunken boat
# 777  C:0  M:0  V:0  W:0  G:0   assist citizen -notification of high risk sex offender
# 830  C:0  M:0  V:0  W:1  G:1   firearm related incidents

# %%
taxonomy.loc[:,'description'] = taxonomy['stat_desc'].apply(lambda x: x.strip())
fields = ['stat','description','category','short_cat','criminal','misdemeanor','violent','weapon','gun']
taxonomy[fields].to_csv('data/taxonomy.csv', index = False)
